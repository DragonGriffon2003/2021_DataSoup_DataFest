# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
#Clean data

# 2019 broadband data file
broad_2019 = pd.read_csv("input/broadband_data_2019November.csv")
# Clean the data set by dropping rows with missing values
broad_2019[' BROADBAND USAGE '] = pd.to_numeric(broad_2019[' BROADBAND USAGE '], errors='coerce')
broad_2019[' BROADBAND AVAILABILITY PER FCC '] = pd.to_numeric(
    broad_2019[' BROADBAND AVAILABILITY PER FCC '], errors='coerce')
nan_value = float("NaN")
broad_2019.replace("-", nan_value, inplace = True)
broad_2019.dropna(subset = [' BROADBAND USAGE '], inplace = True)
broad_2019.dropna(subset = [' BROADBAND AVAILABILITY PER FCC '], inplace = True)
#broad_2019 = broad_2019.sort_values(by = [' BROADBAND AVAILABILITY PER FCC '])

# 2020 broadband data file
broad_2020 = pd.read_csv("input/broadband_data_2020October.csv")
# Clean the data by dropping rows with missing values
broad_2020[' BROADBAND USAGE '] = pd.to_numeric(broad_2020[' BROADBAND USAGE '], errors='coerce')
broad_2020[' BROADBAND AVAILABILITY PER FCC '] = pd.to_numeric(
    broad_2020[' BROADBAND AVAILABILITY PER FCC '], errors='coerce')
broad_2020.replace("-", nan_value, inplace = True)
broad_2020.dropna(subset = [' BROADBAND USAGE '], inplace = True)
broad_2020.dropna(subset = [' BROADBAND AVAILABILITY PER FCC '], inplace = True)
#broad_2020 = broad_2020.sort_values(by = [' BROADBAND AVAILABILITY PER FCC '])

regions = pd.read_csv("input/regions_by_state.csv")

# broadband challenge file
#broad_challenge = pd.read_csv("./input/broadband_data_opendatachallenge.csv")

# broadband by zip code
broad_zip = pd.read_csv("input/broadband_data_zipcode.csv")

# %%
#Plot boxplots of Broadband Availability Averages for 2019 and 2020
#The broadband availability of each state (average of all the counties) represents one point in the plot.
#The overall national availability can thus be depicted here.

#set up windows, axis titles, chart title
plt.rcParams['figure.figsize'] = [10, 8]
plt.ylabel('Broadband Availability')
plt.title('2019-2020 Broadband Availability Averages')

#get unique states (should be 51 including DC)
states = broad_2019['ST'].unique()
#init availiability means
availMeans2019 = []

#get each state in 2019 Broadband Availability by FCC
for s in states :
    uniqueState = broad_2019.loc[broad_2019['ST'] == s]
    #calculate mean of all the counties in that state
    availMeans2019.append(uniqueState[' BROADBAND AVAILABILITY PER FCC '].mean())
    
#do similar for 2020
states = broad_2020['ST'].unique()
availMeans2020 = []
for s in states :
    uniqueState = broad_2020.loc[broad_2020['ST'] == s]
    availMeans2020.append(uniqueState[' BROADBAND AVAILABILITY PER FCC '].mean())

#Boxplot of state availability means by year
plt.boxplot([availMeans2019, availMeans2020])
#Label x axis
plt.xticks([1, 2], ['2019', '2020'])
# Out:
# ([<matplotlib.axis.XTick at 0x22eb3107df0>,
#   <matplotlib.axis.XTick at 0x22eb3107dc0>],
#  [Text(1, 0, '2019'), Text(2, 0, '2020')])

# %%
#Plot boxplots of 2020 Broadband Availability Averages per state
#The broadband availability of a county represents one point of data in a boxplot that represents the state.

#set up plot window
plt.rcParams['figure.figsize'] = [12, 8]
plt.subplot(2,1,1)
plt.xlabel('State')
plt.ylabel('Broadband Availability')
plt.title('2020 Broadband Availability By State')

#get unique states
states = broad_2020['ST'].unique()
#init array that contains arrays of all the county availabilities for state
stateAvails = []
#init array of means for each state (average of all counties in that state)
stateAvailMeans = []

#store data in array
#stateAvails stores each county in state s
for s in states :
    #get the array of availability of all rows with state s
    stateAvails.append(broad_2020[' BROADBAND AVAILABILITY PER FCC '].loc[(broad_2020['ST'] == s)])
    stateRegion = regions['Region'].loc[(regions['ST'] == s)]
    stateAvailMeans.append([s, stateAvails[-1].mean(), stateRegion])

#plot the data
plt.boxplot(stateAvails)
x = np.linspace(1,51, 51)
plt.xticks(x, states, rotation=45)
plt.show()

# %%
#Plot bargraphs of 2020 Broadband Availability means per state

#set up plot window
plt.rcParams['figure.figsize'] = [10, 10]
plt.xlabel('Broadband Availability')
plt.ylabel('State')
plt.title('2020 Broadband Availability Mean By State')
plt.xlim(.5,1)

#sort the data by availability
stateAvailMeans.sort(key=lambda a: a[1])
print(stateAvailMeans)
for s in stateAvailMeans :
    #color by region, red = bottom left and blue = top right
    r = str(s[2])
    if(r.find("Pacific") != -1) :
        clr = "red"
    elif(r.find("Mountain") != -1) :
        clr = "orange"
    elif(r.find("North Central") != -1) :
        clr = "gold"
    elif(r.find("South Central") != -1) :
        clr = "green"
    elif(r.find("South Atlantic") != -1) :
        clr = "skyblue"
    elif(r.find("Middle Atlantic") != -1) :
        clr = "blue"
    elif(r.find("New England") != -1) :
        clr = "indigo"
    else :
        clr = "gray"
        
    #plot the data
    plt.barh(s[0], s[1], color=clr)
# Out:
# [['AR', 0.6169093333333333, 2    West South Central
# Name: Region, dtype: object], ['NV', 0.6440117647058825, 33    Mountain
# Name: Region, dtype: object], ['MS', 0.6447536585365855, 25    East South Central
# Name: Region, dtype: object], ['AK', 0.6560666666666667, 0    None
# Name: Region, dtype: object], ['LA', 0.6841249999999999, 18    West South Central
# Name: Region, dtype: object], ['NM', 0.7015484848484849, 32    Mountain
# Name: Region, dtype: object], ['AL', 0.7036417910447762, 1    East South Central
# Name: Region, dtype: object], ['MT', 0.724925, 26    Mountain
# Name: Region, dtype: object], ['WV', 0.7373018181818182, 49    South Atlantic
# Name: Region, dtype: object], ['AZ', 0.7492533333333334, 3    Mountain
# Name: Region, dtype: object], ['OK', 0.7517051948051944, 36    West South Central
# Name: Region, dtype: object], ['GA', 0.7872157232704403, 10    South Atlantic
# Name: Region, dtype: object], ['MO', 0.7894373913043476, 24    West North Central
# Name: Region, dtype: object], ['SC', 0.8027282608695652, 40    South Atlantic
# Name: Region, dtype: object], ['HI', 0.80744, 11    None
# Name: Region, dtype: object], ['WI', 0.8336166666666666, 48    East North Central
# Name: Region, dtype: object], ['TX', 0.8353173913043472, 43    West South Central
# Name: Region, dtype: object], ['FL', 0.8397223880597013, 9    South Atlantic
# Name: Region, dtype: object], ['NE', 0.8479155555555556, 29    West North Central
# Name: Region, dtype: object], ['CO', 0.8512578125000002, 5    Mountain
# Name: Region, dtype: object], ['MI', 0.8517674698795183, 22    East North Central
# Name: Region, dtype: object], ['OR', 0.8521057142857141, 37    Pacific
# Name: Region, dtype: object], ['ID', 0.8547568181818183, 13    Mountain
# Name: Region, dtype: object], ['VA', 0.8608349206349204, 45    South Atlantic
# Name: Region, dtype: object], ['KS', 0.8640123809523806, 16    West North Central
# Name: Region, dtype: object], ['UT', 0.8674793103448276, 44    Mountain
# Name: Region, dtype: object], ['TN', 0.8712221052631582, 42    East South Central
# Name: Region, dtype: object], ['NC', 0.876017, 27    South Atlantic
# Name: Region, dtype: object], ['KY', 0.876473333333333, 17    East South Central
# Name: Region, dtype: object], ['PA', 0.8888656716417909, 38    Middle Atlantic
# Name: Region, dtype: object], ['IL', 0.8969049019607847, 14    East North Central
# Name: Region, dtype: object], ['WA', 0.9017230769230767, 47    Pacific
# Name: Region, dtype: object], ['VT', 0.9048642857142857, 46    New England
# Name: Region, dtype: object], ['IN', 0.9073913043478261, 15    East North Central
# Name: Region, dtype: object], ['WY', 0.9107130434782609, 50    Mountain
# Name: Region, dtype: object], ['OH', 0.9138193181818184, 35    East North Central
# Name: Region, dtype: object], ['CA', 0.922294827586207, 4    Pacific
# Name: Region, dtype: object], ['SD', 0.9225727272727274, 41    West North Central
# Name: Region, dtype: object], ['IA', 0.9365828282828285, 12    West North Central
# Name: Region, dtype: object], ['ME', 0.9400999999999999, 21    New England
# Name: Region, dtype: object], ['NH', 0.94478, 30    New England
# Name: Region, dtype: object], ['MN', 0.9472540229885056, 23    West North Central
# Name: Region, dtype: object], ['MD', 0.9546041666666666, 20    South Atlantic
# Name: Region, dtype: object], ['MA', 0.9578, 19    New England
# Name: Region, dtype: object], ['ND', 0.9579169811320755, 28    West North Central
# Name: Region, dtype: object], ['NY', 0.9634209677419355, 34    Middle Atlantic
# Name: Region, dtype: object], ['DE', 0.9761000000000001, 8    South Atlantic
# Name: Region, dtype: object], ['DC', 0.9796, 7    South Atlantic
# Name: Region, dtype: object], ['RI', 0.9835, 39    New England
# Name: Region, dtype: object], ['NJ', 0.9850523809523808, 31    Middle Atlantic
# Name: Region, dtype: object], ['CT', 0.9905625, 6    New England
# Name: Region, dtype: object]]

# %%
#Plot boxplots of 2019 Broadband Availability Averages per state
#The broadband availability of a county represents one point of data in a boxplot that represents the state.

#set up plot window
plt.rcParams['figure.figsize'] = [12, 8]
plt.subplot(2,1,1)
plt.xlabel('State')
plt.ylabel('Broadband Availability')
plt.title('2019 Broadband Availability By State')

#get unique states
states = broad_2019['ST'].unique()
#init array that contains arrays of all the county availabilities for state
stateAvails = []
#init array of means for each state (average of all counties in that state)
stateAvailMeans = []

#store data in array
#stateAvails stores each county in state s
for s in states :
    stateAvails.append(broad_2019[' BROADBAND AVAILABILITY PER FCC '].loc[(broad_2019['ST'] == s)])
    stateRegion = regions['Region'].loc[(regions['ST'] == s)]
    stateAvailMeans.append([s, stateAvails[-1].mean(), stateRegion])

#plot the data
plt.boxplot(stateAvails)
x = np.linspace(1,51, 51)
plt.xticks(x, states, rotation=45)
plt.show()

# %%
#Plot bargraphs of 2019 Broadband Availability means per state

#set up plot window
plt.rcParams['figure.figsize'] = [10, 10]
plt.xlabel('Broadband Availability')
plt.ylabel('State')
plt.title('2019 Broadband Availability Mean By State')
plt.xlim(.5,1)

#sort the data by availability
stateAvailMeans.sort(key=lambda a: a[1])
print(stateAvailMeans)
for s in stateAvailMeans :
    #color by region, red = bottom left and blue = top right
    r = str(s[2])
    if(r.find("Pacific") != -1) :
        clr = "red"
    elif(r.find("Mountain") != -1) :
        clr = "orange"
    elif(r.find("North Central") != -1) :
        clr = "gold"
    elif(r.find("South Central") != -1) :
        clr = "green"
    elif(r.find("South Atlantic") != -1) :
        clr = "skyblue"
    elif(r.find("Middle Atlantic") != -1) :
        clr = "blue"
    elif(r.find("New England") != -1) :
        clr = "indigo"
    else :
        clr = "gray"
        
    #plot the data
    plt.barh(s[0], s[1], color=clr)
# Out:
# [['AR', 0.5681333333333332, 2    West South Central
# Name: Region, dtype: object], ['OK', 0.6159210526315791, 36    West South Central
# Name: Region, dtype: object], ['NV', 0.6241176470588236, 33    Mountain
# Name: Region, dtype: object], ['NE', 0.6340860215053765, 29    West North Central
# Name: Region, dtype: object], ['NM', 0.6349999999999998, 32    Mountain
# Name: Region, dtype: object], ['MS', 0.6459756097560974, 25    East South Central
# Name: Region, dtype: object], ['MO', 0.6618260869565216, 24    West North Central
# Name: Region, dtype: object], ['AZ', 0.6673333333333332, 3    Mountain
# Name: Region, dtype: object], ['AL', 0.6721212121212121, 1    East South Central
# Name: Region, dtype: object], ['ID', 0.6773809523809523, 13    Mountain
# Name: Region, dtype: object], ['MT', 0.6799999999999998, 26    Mountain
# Name: Region, dtype: object], ['LA', 0.6800000000000002, 18    West South Central
# Name: Region, dtype: object], ['TX', 0.7021370967741932, 43    West South Central
# Name: Region, dtype: object], ['IL', 0.7280392156862743, 14    East North Central
# Name: Region, dtype: object], ['WY', 0.73, 50    Mountain
# Name: Region, dtype: object], ['WV', 0.7314545454545456, 49    South Atlantic
# Name: Region, dtype: object], ['CO', 0.7504687499999999, 5    Mountain
# Name: Region, dtype: object], ['MI', 0.751219512195122, 22    East North Central
# Name: Region, dtype: object], ['HI', 0.752, 11    None
# Name: Region, dtype: object], ['GA', 0.7627215189873414, 10    South Atlantic
# Name: Region, dtype: object], ['KS', 0.7646153846153846, 16    West North Central
# Name: Region, dtype: object], ['SC', 0.7734782608695653, 40    South Atlantic
# Name: Region, dtype: object], ['IN', 0.7742391304347822, 15    East North Central
# Name: Region, dtype: object], ['WI', 0.7879166666666672, 48    East North Central
# Name: Region, dtype: object], ['AK', 0.78875, 0    None
# Name: Region, dtype: object], ['TN', 0.7986315789473684, 42    East South Central
# Name: Region, dtype: object], ['OR', 0.8011428571428569, 37    Pacific
# Name: Region, dtype: object], ['CA', 0.8099999999999999, 4    Pacific
# Name: Region, dtype: object], ['KY', 0.8125833333333333, 17    East South Central
# Name: Region, dtype: object], ['VA', 0.81608, 45    South Atlantic
# Name: Region, dtype: object], ['VT', 0.8164285714285713, 46    New England
# Name: Region, dtype: object], ['FL', 0.8229850746268659, 9    South Atlantic
# Name: Region, dtype: object], ['UT', 0.8328571428571426, 44    Mountain
# Name: Region, dtype: object], ['IA', 0.8366666666666666, 12    West North Central
# Name: Region, dtype: object], ['OH', 0.846590909090909, 35    East North Central
# Name: Region, dtype: object], ['SD', 0.8495384615384616, 41    West North Central
# Name: Region, dtype: object], ['NC', 0.8613999999999997, 27    South Atlantic
# Name: Region, dtype: object], ['PA', 0.8655223880597013, 38    Middle Atlantic
# Name: Region, dtype: object], ['ME', 0.8712500000000001, 21    New England
# Name: Region, dtype: object], ['WA', 0.892051282051282, 47    Pacific
# Name: Region, dtype: object], ['MN', 0.8944827586206894, 23    West North Central
# Name: Region, dtype: object], ['ND', 0.9003773584905658, 28    West North Central
# Name: Region, dtype: object], ['NH', 0.9019999999999999, 30    New England
# Name: Region, dtype: object], ['NY', 0.9095161290322582, 34    Middle Atlantic
# Name: Region, dtype: object], ['MA', 0.9557142857142857, 19    New England
# Name: Region, dtype: object], ['MD', 0.9649999999999999, 20    South Atlantic
# Name: Region, dtype: object], ['DE', 0.9700000000000001, 8    South Atlantic
# Name: Region, dtype: object], ['DC', 0.98, 7    South Atlantic
# Name: Region, dtype: object], ['RI', 0.984, 39    New England
# Name: Region, dtype: object], ['NJ', 0.9885714285714284, 31    Middle Atlantic
# Name: Region, dtype: object], ['CT', 0.9887500000000001, 6    New England
# Name: Region, dtype: object]]

# %%
#Plot boxplots of 2020 Broadband Usage Averages per state
#The broadband availability of a county represents one point of data in a boxplot that represents the state.

#set up plot window
plt.rcParams['figure.figsize'] = [12, 8]
plt.subplot(2,1,1)
plt.xlabel('State')
plt.ylabel('Broadband Usage')
plt.title('2020 Broadband Usage By State')

#get unique states
states = broad_2020['ST'].unique()
#init array that contains arrays of all the county availabilities for state
stateUse = []
#init array of means for each state (average of all counties in that state)
stateUseMeans = []

#store data in array
#stateAvails stores each county in state s
for s in states :
    stateUse.append(broad_2020[' BROADBAND USAGE '].loc[(broad_2020['ST'] == s)])
    stateRegion = regions['Region'].loc[(regions['ST'] == s)]
    stateUseMeans.append([s, stateUse[-1].mean(), stateRegion])

#plot the data
plt.boxplot(stateUse)
x = np.linspace(1,51, 51)
plt.xticks(x, states, rotation=45)
plt.show()

# %%
#Plot bargraphs of 2020 Broadband Usage means per state

#set up plot window
plt.rcParams['figure.figsize'] = [10, 10]
plt.xlabel('Broadband Usage')
plt.ylabel('State')
plt.title('2020 Broadband Usage Mean By State')
plt.xlim(0,1)

#sort the data by availability
stateUseMeans.sort(key=lambda a: a[1])
print(stateUseMeans)
for s in stateUseMeans :
    #color by region, red = bottom left and blue = top right
    r = str(s[2])
    if(r.find("Pacific") != -1) :
        clr = "red"
    elif(r.find("Mountain") != -1) :
        clr = "orange"
    elif(r.find("North Central") != -1) :
        clr = "gold"
    elif(r.find("South Central") != -1) :
        clr = "green"
    elif(r.find("South Atlantic") != -1) :
        clr = "skyblue"
    elif(r.find("Middle Atlantic") != -1) :
        clr = "blue"
    elif(r.find("New England") != -1) :
        clr = "indigo"
    else :
        clr = "gray"
        
    #plot the data
    plt.barh(s[0], s[1], color=clr)
# Out:
# [['MS', 0.20037804878048776, 25    East South Central
# Name: Region, dtype: object], ['AR', 0.22662666666666673, 2    West South Central
# Name: Region, dtype: object], ['WV', 0.2527636363636363, 49    South Atlantic
# Name: Region, dtype: object], ['OK', 0.27592207792207785, 36    West South Central
# Name: Region, dtype: object], ['LA', 0.2840937500000001, 18    West South Central
# Name: Region, dtype: object], ['AL', 0.2895970149253731, 1    East South Central
# Name: Region, dtype: object], ['MO', 0.2916260869565218, 24    West North Central
# Name: Region, dtype: object], ['KY', 0.3021500000000001, 17    East South Central
# Name: Region, dtype: object], ['NE', 0.3096, 29    West North Central
# Name: Region, dtype: object], ['NM', 0.32415151515151513, 32    Mountain
# Name: Region, dtype: object], ['TX', 0.33995652173913044, 43    West South Central
# Name: Region, dtype: object], ['MT', 0.3411964285714286, 26    Mountain
# Name: Region, dtype: object], ['AK', 0.3511904761904763, 0    None
# Name: Region, dtype: object], ['NV', 0.3543529411764706, 33    Mountain
# Name: Region, dtype: object], ['IN', 0.3560326086956523, 15    East North Central
# Name: Region, dtype: object], ['ID', 0.35849999999999993, 13    Mountain
# Name: Region, dtype: object], ['KS', 0.3624095238095238, 16    West North Central
# Name: Region, dtype: object], ['IL', 0.37073529411764716, 14    East North Central
# Name: Region, dtype: object], ['SC', 0.3743260869565217, 40    South Atlantic
# Name: Region, dtype: object], ['GA', 0.3769559748427675, 10    South Atlantic
# Name: Region, dtype: object], ['WY', 0.3959130434782608, 50    Mountain
# Name: Region, dtype: object], ['MI', 0.40275903614457814, 22    East North Central
# Name: Region, dtype: object], ['IA', 0.40357575757575753, 12    West North Central
# Name: Region, dtype: object], ['TN', 0.4050105263157895, 42    East South Central
# Name: Region, dtype: object], ['WI', 0.4154722222222223, 48    East North Central
# Name: Region, dtype: object], ['VT', 0.41785714285714287, 46    New England
# Name: Region, dtype: object], ['SD', 0.41959090909090924, 41    West North Central
# Name: Region, dtype: object], ['ME', 0.4379374999999999, 21    New England
# Name: Region, dtype: object], ['NC', 0.44252999999999987, 27    South Atlantic
# Name: Region, dtype: object], ['CO', 0.44937499999999975, 5    Mountain
# Name: Region, dtype: object], ['MN', 0.4518045977011496, 23    West North Central
# Name: Region, dtype: object], ['OH', 0.45543181818181805, 35    East North Central
# Name: Region, dtype: object], ['AZ', 0.4583333333333333, 3    Mountain
# Name: Region, dtype: object], ['PA', 0.46992537313432836, 38    Middle Atlantic
# Name: Region, dtype: object], ['VA', 0.4739603174603174, 45    South Atlantic
# Name: Region, dtype: object], ['ND', 0.4768867924528304, 28    West North Central
# Name: Region, dtype: object], ['WA', 0.4869743589743589, 47    Pacific
# Name: Region, dtype: object], ['FL', 0.5072835820895523, 9    South Atlantic
# Name: Region, dtype: object], ['CA', 0.529051724137931, 4    Pacific
# Name: Region, dtype: object], ['OR', 0.534342857142857, 37    Pacific
# Name: Region, dtype: object], ['HI', 0.5518, 11    None
# Name: Region, dtype: object], ['NY', 0.5717741935483868, 34    Middle Atlantic
# Name: Region, dtype: object], ['UT', 0.5840689655172412, 44    Mountain
# Name: Region, dtype: object], ['DC', 0.658, 7    South Atlantic
# Name: Region, dtype: object], ['NH', 0.6648, 30    New England
# Name: Region, dtype: object], ['CT', 0.668375, 6    New England
# Name: Region, dtype: object], ['MD', 0.6715833333333333, 20    South Atlantic
# Name: Region, dtype: object], ['MA', 0.7052142857142857, 19    New England
# Name: Region, dtype: object], ['DE', 0.7263333333333333, 8    South Atlantic
# Name: Region, dtype: object], ['NJ', 0.7339523809523811, 31    Middle Atlantic
# Name: Region, dtype: object], ['RI', 0.7411999999999999, 39    New England
# Name: Region, dtype: object]]
