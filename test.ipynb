# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
brod_2020 = pd.read_csv('./data/broadband_data_2020October.csv')
brod_2019 = pd.read_csv('./data/broadband_data_2019November.csv')
brod_zip = pd.read_csv('./data/broadband_data_zipcode.csv')

# %%
brod_2020
# Out:
#      Data is to be used only for analysis purposes related to broadband mapping  \
# 0            For questions contact bbdata@microsoft.com
# 1                                                   NaN
# 2     Broadband availability in the United States ba...
# 3     Fourteenth Broadband Deployment Report: https:...
# 4                     Form 477 data as of December 2019
# ...                                                 ...
# 3155                                                 WY
# 3156                                                 WY
# 3157                                                 WY
# 3158                                                 WY
# 3159                                                 WY
#
#      Unnamed: 1         Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0           NaN                NaN        NaN        NaN
# 1           NaN                NaN        NaN        NaN
# 2           NaN                NaN        NaN        NaN
# ...

# %%
brod_2019
# Out:
#       ST  COUNTY ID        COUNTY NAME  BROADBAND AVAILABILITY PER FCC   \
# 0     AL       1001     Autauga County                            0.81
# 1     AL       1003     Baldwin County                            0.88
# 2     AL       1005     Barbour County                            0.59
# 3     AL       1007        Bibb County                            0.29
# 4     AL       1009      Blount County                            0.69
# ...   ..        ...                ...                              ...
# 3138  WY      56037  Sweetwater County                            0.93
# 3139  WY      56039       Teton County                            0.94
# 3140  WY      56041       Uinta County                            0.66
# 3141  WY      56043    Washakie County                            0.76
# 3142  WY      56045      Weston County                            0.34
#
#       BROADBAND USAGE
# 0                0.28
# 1                0.30
# 2                0.18
# ...

# %%
brod_zip
# Out:
#        ST COUNTY NAME  COUNTY ID  POSTAL CODE  BROADBAND USAGE  \
# 0      SC   Abbeville      45001        29639            0.948
# 1      SC   Abbeville      45001        29620            0.398
# 2      SC   Abbeville      45001        29659            0.206
# 3      SC   Abbeville      45001        29638            0.369
# 4      SC   Abbeville      45001        29628            0.221
# ...    ..         ...        ...          ...              ...
# 32730  TX      Zavala      48507        78839            0.514
# 32731  TX      Zavala      48507        78872            0.071
# 32732  SD     Ziebach      46137        57622            0.000
# 32733  SD     Ziebach      46137        57748            0.000
# 32734  SD     Ziebach      46137        57623            0.299
#
#        ERROR RANGE (MAE)(+/-)  ERROR RANGE (95%)(+/-)    MSD
# 0                       0.034                   0.110  0.002
# 1                       0.002                   0.007  0.000
# ...

# %%
#Plot Broadband Availability per FCC on x, Broadband Usage on y

'''
Columns:
[:, 0] = State
[:, 1] = County ID
[:, 2] = County Name
[:, 3] = Broadband Availability per FCC
[:, 4] = Broadband Usage
'''
#Convent pandas dataframe to numpy array
brod_2020_array = brod_2020.to_numpy();

#Set up plot window
plt.rcParams['figure.figsize'] = [10,8]
#Plot Broadband Availability per FCC on x, Broadband Usage on y
plt.scatter(brod_2020_array[20:, 3], brod_2020_array[20:, 4], marker = '.')
